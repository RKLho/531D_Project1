# %%
import Part1, Part2, Part4
import tools
Data_Highway = tools.read_trajectories("../data/highway.csv")
data = tools.reconstruct(Data_Highway)

# %% [markdown]
# ## Part 4

# %% [markdown]
# ### PDTW
# Path Visualization before and after aggregation

# %%
T1 = data[0]
T2 = data[1]
_a, b = Part1.dtw(T1, T2)
c = 2 # aggregate factor
T3 = Part4.paa(T1, c)
T4 = Part4.paa(T2, c)
_c, d = Part1.dtw(T3, T4)
c=4
T5 = Part4.paa(T1, c)
T6 = Part4.paa(T2, c)
_c, e = Part1.dtw(T5, T6)
tools.draw_assignment(T1, T2, b, 'Pure DTW Method', '../images/part4/beforePAA')
tools.draw_assignment(T3, T4, d, 'PDTW with c = 2', '../images/part4/PDTW2')
tools.draw_assignment(T5, T6, e, 'PDTW with c = 4', '../images/part4/PDTW4')

# %% [markdown]
# ### Time difference between dtw and pdtw

# %%
import Part1, Part4
import tools
import time
Data_Highway = tools.read_trajectories("../data/highway.csv")
tracjtories = tools.reconstruct(Data_Highway)

first = time.time()
c = 2   # aggregate factor
for id in range(1, len(tracjtories)):
    T1 = Part4.paa(tracjtories[id-1], c)
    T2 = Part4.paa(tracjtories[id], c)
    a, b = Part1.dtw(T1, T2)
    
print("Time for pdtw with c=2:", time.time()-first)

first = time.time()
c = 5  
for id in range(1, len(tracjtories)):
    T1 = Part4.paa(tracjtories[id-1], c)
    T2 = Part4.paa(tracjtories[id], c)
    a, b = Part1.dtw(T1, T2)
    
print("Time for pdtw with c=5:", time.time()-first)

first = time.time()
for id in range(1, len(tracjtories)):
    T1 = tracjtories[id-1]
    T2 = tracjtories[id]
    a, b = Part1.dtw(T1, T2)
print("Time for dtw:", time.time()-first)
# Out:
# Time for pdtw with c=2: 1.066864252090454
# Time for pdtw with c=5: 0.25584912300109863
# Time for dtw: 2.5442991256713867

# %% [markdown]
# ### Longest Common Subsequence (LCSS)

# %%
T1 = data[0]
T2 = data[1]
_a, b = Part4.lcssDist(T1, T2)
tools.draw_assignment(T1, T2, b, 'LCSS Method', '../images/part4/lcss')

# %% [markdown]
# - Read noise data and plot
# We find that it is robust under noise

# %%
import Part1, Part2, Part4
import tools
noise = tools.read_trajectories("../data/noise.csv")
noise_data = tools.reconstruct(noise)

T1 = noise_data[0]
T2 = noise_data[1]
_a, b = Part4.lcssDist(T1, T2)
_a, c = Part1.dtw(T1, T2)
tools.draw_assignment(T1, T2, b, 'Noise data with LCSS', '../images/part4/lcssnoise')
tools.draw_assignment(T1, T2, c, 'Noise data with DTW', '../images/part4/dtwnoise')
